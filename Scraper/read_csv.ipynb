# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
data = pd.read_csv('C:/Users/sylva/OneDrive/Bureau/scrap_project_MD4/Projet_entreprise/Data/csv/Île-de-France_POLE EMPLOI.csv', sep=';')

# %%
data
# Out:
#          Services                                     Localisation  \
# 0     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 1     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 2     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 3     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 4     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# ...           ...                                              ...
# 2331  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2332  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2333  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2334  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2335  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
#
#              Region            Auteur  \
# 0     Île-de-France     Gerard Ceotto
# 1     Île-de-France       kamel benai
# 2     Île-de-France          Weendy K
# 3     Île-de-France          Soraya B
# 4     Île-de-France  HALLA EL MELIANI
# ...             ...               ...
# 2331  Île-de-France               M P
# 2332  Île-de-France   Cédric Becquart
# 2333  Île-de-France             Laura
# 2334  Île-de-France   Charles Poirier
# 2335  Île-de-France    Estelle Barbey
#
#                                            Commentaires        Date  Etoile  \
# 0     Très bien accueilli entretien a venir pour le ...  22/05/2022     5.0
# 1                                         Adress fausse  23/05/2018     1.0
# 2     Très mauvaise expérience avec Élisabeth, qui a...  23/12/2022     1.0
# 3     A fuir !!! Mon expérience avec mon conseiller ...  21/02/2023     1.0
# 4     TATIANA LA CONSEILLÈRE INDEMNITÉ LA PLUS NULLE...  08/05/2023     1.0
# ...                                                 ...         ...     ...
# 2331  Mme Calicat au top,trés gentille et toujours à...  22/05/2022     5.0
# 2332  Agence correct, je ne me déplacerais plus auss...  22/05/2020     1.0
# 2333      Personnel très sympathique, locaux agréables.  23/05/2019     5.0
# 2334                                          Dès nul !  23/05/2017     1.0
# 2335                            De vrais incompétents !  22/05/2020     1.0
#
#      Unnamed: 7
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2331        NaN
# 2332        NaN
# 2333        NaN
# 2334        NaN
# 2335        NaN
#
# [2336 rows x 8 columns]

# %%
data.shape
# Out:
# (2336, 8)

# %%
data['Etoile'].value_counts()
# Out:
# 1.0    1305
# 5.0     616
# 4.0     154
# 3.0     131
# 2.0     104
# Name: Etoile, dtype: int64

# %%
Labels = ['1 étoile', '2 étoiles', '3 étoiles','4 étoiles','5 étoiles']
sizes = [1305, 104,131, 154, 616]
color = ['#ff0000', '#ffa700', '#fff400', '#a3ff00', '#2cba00']
explode = (0.05,0.05,0.05,0.05)

# %%
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = color, labels=Labels, autopct='%1.1f%%', startangle=90)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
# Créer une nouvelle colonne "Ville" en extrayant le nom de la ville de la colonne "Localisation"
data["Ville"] = data["Localisation"].str.split(',').str[-1].str.strip()

# Afficher le DataFrame mis à jour
data
# Out:
#          Services                                     Localisation  \
# 0     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 1     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 2     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 3     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 4     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# ...           ...                                              ...
# 2331  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2332  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2333  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2334  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2335  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
#
#              Region            Auteur  \
# 0     Île-de-France     Gerard Ceotto
# 1     Île-de-France       kamel benai
# 2     Île-de-France          Weendy K
# 3     Île-de-France          Soraya B
# 4     Île-de-France  HALLA EL MELIANI
# ...             ...               ...
# 2331  Île-de-France               M P
# 2332  Île-de-France   Cédric Becquart
# 2333  Île-de-France             Laura
# 2334  Île-de-France   Charles Poirier
# 2335  Île-de-France    Estelle Barbey
#
#                                            Commentaires        Date  Etoile  \
# 0     Très bien accueilli entretien a venir pour le ...  22/05/2022     5.0
# 1                                         Adress fausse  23/05/2018     1.0
# 2     Très mauvaise expérience avec Élisabeth, qui a...  23/12/2022     1.0
# 3     A fuir !!! Mon expérience avec mon conseiller ...  21/02/2023     1.0
# 4     TATIANA LA CONSEILLÈRE INDEMNITÉ LA PLUS NULLE...  08/05/2023     1.0
# ...                                                 ...         ...     ...
# 2331  Mme Calicat au top,trés gentille et toujours à...  22/05/2022     5.0
# 2332  Agence correct, je ne me déplacerais plus auss...  22/05/2020     1.0
# 2333      Personnel très sympathique, locaux agréables.  23/05/2019     5.0
# 2334                                          Dès nul !  23/05/2017     1.0
# 2335                            De vrais incompétents !  22/05/2020     1.0
#
#      Unnamed: 7                     Ville
# 0           NaN    95700 Roissy-en-France
# 1           NaN    95700 Roissy-en-France
# 2           NaN  93290 Tremblay-en-France
# 3           NaN  93290 Tremblay-en-France
# 4           NaN  93290 Tremblay-en-France
# ...         ...                       ...
# 2331        NaN          91160 Longjumeau
# 2332        NaN          91160 Longjumeau
# 2333        NaN          91160 Longjumeau
# 2334        NaN          91160 Longjumeau
# 2335        NaN          91160 Longjumeau
#
# [2336 rows x 9 columns]

# %%
etoiles_par_ville = data.groupby('Ville')['Etoile'].value_counts()
print(etoiles_par_ville)
# Out:
# Ville             Etoile
# Antony            1.0       19
#                   5.0        7
#                   2.0        1
# Argenteuil        1.0       16
#                   4.0        2
#                             ..
# Vitry-sur-Seine   3.0        1
#                   5.0        1
# Épinay-sur-Seine  1.0       13
#                   5.0        4
#                   4.0        1
# Name: Etoile, Length: 362, dtype: int64

# %%
# Définir une expression régulière pour extraire le nom de la ville
pattern = r"\b(\w+(?:-\w+)*)$"

# %%
# Appliquer l'expression régulière pour extraire le nom de la ville dans la colonne "Localisation"
data["Ville"] = data["Localisation"].str.extract(pattern, expand=False)

# %%
data
# Out:
#          Services                                     Localisation  \
# 0     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 1     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 2     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 3     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 4     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# ...           ...                                              ...
# 2331  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2332  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2333  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2334  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2335  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
#
#              Region            Auteur  \
# 0     Île-de-France     Gerard Ceotto
# 1     Île-de-France       kamel benai
# 2     Île-de-France          Weendy K
# 3     Île-de-France          Soraya B
# 4     Île-de-France  HALLA EL MELIANI
# ...             ...               ...
# 2331  Île-de-France               M P
# 2332  Île-de-France   Cédric Becquart
# 2333  Île-de-France             Laura
# 2334  Île-de-France   Charles Poirier
# 2335  Île-de-France    Estelle Barbey
#
#                                            Commentaires        Date  Etoile  \
# 0     Très bien accueilli entretien a venir pour le ...  22/05/2022     5.0
# 1                                         Adress fausse  23/05/2018     1.0
# 2     Très mauvaise expérience avec Élisabeth, qui a...  23/12/2022     1.0
# 3     A fuir !!! Mon expérience avec mon conseiller ...  21/02/2023     1.0
# 4     TATIANA LA CONSEILLÈRE INDEMNITÉ LA PLUS NULLE...  08/05/2023     1.0
# ...                                                 ...         ...     ...
# 2331  Mme Calicat au top,trés gentille et toujours à...  22/05/2022     5.0
# 2332  Agence correct, je ne me déplacerais plus auss...  22/05/2020     1.0
# 2333      Personnel très sympathique, locaux agréables.  23/05/2019     5.0
# 2334                                          Dès nul !  23/05/2017     1.0
# 2335                            De vrais incompétents !  22/05/2020     1.0
#
#      Unnamed: 7               Ville
# 0           NaN    Roissy-en-France
# 1           NaN    Roissy-en-France
# 2           NaN  Tremblay-en-France
# 3           NaN  Tremblay-en-France
# 4           NaN  Tremblay-en-France
# ...         ...                 ...
# 2331        NaN          Longjumeau
# 2332        NaN          Longjumeau
# 2333        NaN          Longjumeau
# 2334        NaN          Longjumeau
# 2335        NaN          Longjumeau
#
# [2336 rows x 9 columns]

# %%
# Suppression de la colonne unitile
data.drop("Unnamed: 7", axis=1, inplace=True)

# %%
data
# Out:
#          Services                                     Localisation  \
# 0     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 1     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 2     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 3     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 4     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# ...           ...                                              ...
# 2331  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2332  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2333  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2334  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2335  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
#
#              Region            Auteur  \
# 0     Île-de-France     Gerard Ceotto
# 1     Île-de-France       kamel benai
# 2     Île-de-France          Weendy K
# 3     Île-de-France          Soraya B
# 4     Île-de-France  HALLA EL MELIANI
# ...             ...               ...
# 2331  Île-de-France               M P
# 2332  Île-de-France   Cédric Becquart
# 2333  Île-de-France             Laura
# 2334  Île-de-France   Charles Poirier
# 2335  Île-de-France    Estelle Barbey
#
#                                            Commentaires        Date  Etoile  \
# 0     Très bien accueilli entretien a venir pour le ...  22/05/2022     5.0
# 1                                         Adress fausse  23/05/2018     1.0
# 2     Très mauvaise expérience avec Élisabeth, qui a...  23/12/2022     1.0
# 3     A fuir !!! Mon expérience avec mon conseiller ...  21/02/2023     1.0
# 4     TATIANA LA CONSEILLÈRE INDEMNITÉ LA PLUS NULLE...  08/05/2023     1.0
# ...                                                 ...         ...     ...
# 2331  Mme Calicat au top,trés gentille et toujours à...  22/05/2022     5.0
# 2332  Agence correct, je ne me déplacerais plus auss...  22/05/2020     1.0
# 2333      Personnel très sympathique, locaux agréables.  23/05/2019     5.0
# 2334                                          Dès nul !  23/05/2017     1.0
# 2335                            De vrais incompétents !  22/05/2020     1.0
#
#                    Ville
# 0       Roissy-en-France
# 1       Roissy-en-France
# 2     Tremblay-en-France
# 3     Tremblay-en-France
# 4     Tremblay-en-France
# ...                  ...
# 2331          Longjumeau
# 2332          Longjumeau
# 2333          Longjumeau
# 2334          Longjumeau
# 2335          Longjumeau
#
# [2336 rows x 8 columns]

# %%
df = pd.read_csv('C:/Users/sylva/OneDrive/Bureau/scrap_project_MD4/Projet_entreprise/Data/csv/Count_Ville.csv', sep=',')

df
# Out:
#                        Ville  Score
# 0                     Antony     24
# 1                 Argenteuil     19
# 2         Asnières-sur-Seine      9
# 3              Aubervilliers     23
# 4           Aulnay-sous-Bois     21
# ..                       ...    ...
# 89  Villeneuve-Saint-Georges     11
# 90                 Vincennes     14
# 91            Viry-Châtillon     15
# 92           Vitry-sur-Seine     13
# 93          Épinay-sur-Seine     17
#
# [94 rows x 2 columns]

# %%
# Obtenir les valeurs uniques de la colonne "Ville"
unique_villes = data['Ville'].unique()

# Afficher les valeurs uniques
for ville in unique_villes:
    print(ville)
# Out:
# Roissy-en-France
# Tremblay-en-France
# Gonesse
# Sarcelles
# Aulnay-sous-Bois
# Domont
# Sevran
# Montataire
# Blanc-Mesnil
# Garges-lès-Gonesse
# Saint-Maximin
# Mitry-Mory
# Persan
# Stains
# Courneuve
# Livry-Gargan
# Saint-Denis
# Aubervilliers
# Montmorency
# Pantin
# Drancy
# Paris
# Nogent-sur-Oise
# Épinay-sur-Seine
# Bobigny
# Bondy
# Clichy-sous-Bois
# Saint-Ouen-sur-Seine
# Saint-Gratien
# Rosny-sous-Bois
# Noisy-le-Sec
# Taverny
# Clichy
# Asnières-sur-Seine
# Ermont
# Gennevilliers
# Argenteuil
# Colombes
# Chelles
# Herblay-sur-Seine
# Lagny-sur-Marne
# Fontenay-sous-Bois
# Torcy
# Neuilly-sur-Marne
# Montreuil
# Courbevoie
# Bezons
# Levallois-Perret
# Champigny-sur-Marne
# Meaux
# Nogent-sur-Marne
# Noisy-le-Grand
# Chennevières-sur-Marne
# Vincennes
# Chessy
# Puteaux
# Crépy-en-Valois
# Aumône
# Conflans-Sainte-Honorine
# Saint-Maur-des-Fossés
# Nanterre
# Ivry-sur-Seine
# Issy-les-Moulineaux
# Maisons-Alfort
# Vitry-sur-Seine
# Cergy
# Rueil-Malmaison
# Boulogne-Billancourt
# Cachan
# Montrouge
# Sartrouville
# Pontault-Combault
# Compiègne
# Villejuif
# Méru
# Antony
# Sucy-en-Brie
# Fitz-James
# Choisy-le-Roi
# Haÿ-les-Roses
# Créteil
# Bagneux
# Saint-Germain-en-Laye
# Poissy
# Viry-Châtillon
# Margny-lès-Compiègne
# Villeneuve-Saint-Georges
# Savigny-sur-Orge
# Pré-Saint-Gervais
# Brunoy
# Versailles
# Ferté-sous-Jouarre
# Brie-Comte-Robert
# Longjumeau

# %%
# Calculer le nombre de services par ville et nombre d'étoiles
result = data.groupby(["Ville", "Date"]).mean()
result = result.rename(columns={"Services": "Nombre de services", "Date": "Période"})

# %%
result
# Out:
#                                Etoile
# Ville            Date
# Antony           21/02/2023  1.000000
#                  22/05/2020  1.000000
#                  22/05/2021  1.307692
#                  22/05/2022  4.000000
#                  23/05/2019  1.000000
# ...                               ...
# Épinay-sur-Seine 23/05/2018  2.750000
#                  23/05/2019  1.000000
#                  23/11/2022  1.000000
#                  24/09/2022  5.000000
#                  24/10/2022  1.000000
#
# [878 rows x 1 columns]

# %%
print(len(ville))
# Out:
# 10

# %%
# result.to_csv(f'../Data/csv/Île-de-France_service.csv', index=False, sep=';')

# %%
data
# Out:
#          Services                                     Localisation  \
# 0     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 1     Pôle emploi          5 Rue du Cercle, 95700 Roissy-en-France
# 2     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 3     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# 4     Pôle emploi  43 Av. Nelson Mandela, 93290 Tremblay-en-France
# ...           ...                                              ...
# 2331  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2332  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2333  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2334  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
# 2335  Pôle emploi                 30 Rue Maurice, 91160 Longjumeau
#
#              Region            Auteur  \
# 0     Île-de-France     Gerard Ceotto
# 1     Île-de-France       kamel benai
# 2     Île-de-France          Weendy K
# 3     Île-de-France          Soraya B
# 4     Île-de-France  HALLA EL MELIANI
# ...             ...               ...
# 2331  Île-de-France               M P
# 2332  Île-de-France   Cédric Becquart
# 2333  Île-de-France             Laura
# 2334  Île-de-France   Charles Poirier
# 2335  Île-de-France    Estelle Barbey
#
#                                            Commentaires        Date  Etoile  \
# 0     Très bien accueilli entretien a venir pour le ...  22/05/2022     5.0
# 1                                         Adress fausse  23/05/2018     1.0
# 2     Très mauvaise expérience avec Élisabeth, qui a...  23/12/2022     1.0
# 3     A fuir !!! Mon expérience avec mon conseiller ...  21/02/2023     1.0
# 4     TATIANA LA CONSEILLÈRE INDEMNITÉ LA PLUS NULLE...  08/05/2023     1.0
# ...                                                 ...         ...     ...
# 2331  Mme Calicat au top,trés gentille et toujours à...  22/05/2022     5.0
# 2332  Agence correct, je ne me déplacerais plus auss...  22/05/2020     1.0
# 2333      Personnel très sympathique, locaux agréables.  23/05/2019     5.0
# 2334                                          Dès nul !  23/05/2017     1.0
# 2335                            De vrais incompétents !  22/05/2020     1.0
#
#                    Ville
# 0       Roissy-en-France
# 1       Roissy-en-France
# 2     Tremblay-en-France
# 3     Tremblay-en-France
# 4     Tremblay-en-France
# ...                  ...
# 2331          Longjumeau
# 2332          Longjumeau
# 2333          Longjumeau
# 2334          Longjumeau
# 2335          Longjumeau
#
# [2336 rows x 8 columns]

# %%
    # Charger les données des scores des villes d'Île-de-France
df = pd.read_csv('C:/Users/sylva/OneDrive/Bureau/scrap_project_MD4/Projet_entreprise/Data/csv/taux_ville.csv', sep=';')
df
# Out:
#                        Ville  Nombre d’avis négatif  Nombre d’avis Positif  \
# 0                     Antony                     15                      8
# 1                 Argenteuil                     15                      3
# 2         Asnières-sur-Seine                      6                      3
# 3              Aubervilliers                     12                     10
# 4           Aulnay-sous-Bois                     16                      5
# ..                       ...                    ...                    ...
# 89  Villeneuve-Saint-Georges                      6                      5
# 90                 Vincennes                      8                      5
# 91            Viry-Châtillon                      9                      6
# 92           Vitry-sur-Seine                     10                      3
# 93          Épinay-sur-Seine                     11                      5
#
#     Nombre d’avis Neutre
# 0                      1
# 1                      1
# 2                      0
# 3                      1
# 4                      0
# ..                   ...
# 89                     0
# 90                     1
# 91                     0
# 92                     0
# 93                     1
#
# [94 rows x 4 columns]

# %%
dfrm = pd.read_csv('../Data/csv/taux_ville.csv', sep=';')
dfrm
# Out:
#                        Ville  Nombre d’avis négatif  Nombre d’avis Positif  \
# 0                     Antony                     15                      8
# 1                 Argenteuil                     15                      3
# 2         Asnières-sur-Seine                      6                      3
# 3              Aubervilliers                     12                     10
# 4           Aulnay-sous-Bois                     16                      5
# ..                       ...                    ...                    ...
# 89  Villeneuve-Saint-Georges                      6                      5
# 90                 Vincennes                      8                      5
# 91            Viry-Châtillon                      9                      6
# 92           Vitry-sur-Seine                     10                      3
# 93          Épinay-sur-Seine                     11                      5
#
#     Nombre d’avis Neutre
# 0                      1
# 1                      1
# 2                      0
# 3                      1
# 4                      0
# ..                   ...
# 89                     0
# 90                     1
# 91                     0
# 92                     0
# 93                     1
#
# [94 rows x 4 columns]

# %%
# Extraire l'année à partir de la colonne "Date de publication"
dfrm['Year'] = pd.to_datetime(dfrm['Date de publication'], format='%d/%m/%Y').dt.year

# Récupérer toutes les années du CSV au format "2023"
annees = dfrm['Year'].unique()

print(annees)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\sylva\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date de publication'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28632\2035112886.py in <module>
#       1 # Extraire l'année à partir de la colonne "Date de publication"
# ----> 2 dfrm['Year'] = pd.to_datetime(dfrm['Date de publication'], format='%d/%m/%Y').dt.year
#       3
#       4 # Récupérer toutes les années du CSV au format "2023"
#       5 annees = dfrm['Year'].unique()
#
# c:\Users\sylva\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\sylva\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Date de publication'
